# %%
import numpy as np
import pandas as pd

from sklearn.metrics import mean_squared_error, r2_score
from sklearn import linear_model
from sklearn.metrics import accuracy_score 
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("houseprice.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6394 entries, 0 to 6393
# Data columns (total 21 columns):
# id               6394 non-null int64
# date             6394 non-null object
# price            6394 non-null float64
# bedrooms         6394 non-null int64
# bathrooms        6394 non-null float64
# sqft_living      6394 non-null int64
# sqft_lot         6394 non-null int64
# floors           6394 non-null float64
# waterfront       6394 non-null int64
# view             6394 non-null int64
# condition        6394 non-null int64
# grade            6394 non-null int64
# sqft_above       6394 non-null int64
# sqft_basement    6393 non-null float64
# yr_built         6393 non-null float64
# yr_renovated     6393 non-null float64
# zipcode          6393 non-null float64
# lat              6393 non-null float64
# long             6393 non-null float64
# sqft_living15    6393 non-null float64
# sqft_lot15       6393 non-null float64
# dtypes: float64(11), int64(9), object(1)
# memory usage: 1.0+ MB

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0            0.0    1955.0           0.0  98178.0  47.5112 -122.257
# 1          400.0    1951.0        1991.0  98125.0  47.7210 -122.319
# 2            0.0    1933.0           0.0  98028.0  47.7379 -122.233
# 3          910.0    1965.0           0.0  98136.0  47.5208 -122.393
# 4            0.0    1987.0           0.0  98074.0  47.6168 -122.045
#
#    sqft_living15  sqft_lot15
# 0         1340.0      5650.0
# 1         1690.0      7639.0
# 2         2720.0      8062.0
# 3         1360.0      5000.0
# 4         1800.0      7503.0
#
# [5 rows x 21 columns]

# %%
conv_dates = [1 if values == 2014 else 0 for values in df.date ]
df['date'] = conv_dates

# %%
df = df.drop(['id', 'lat', 'long'], axis=1)

# %%
df.head()
# Out:
#    date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     0  221900.0         3       1.00         1180      5650     1.0
# 1     0  538000.0         3       2.25         2570      7242     2.0
# 2     0  180000.0         2       1.00          770     10000     1.0
# 3     0  604000.0         4       3.00         1960      5000     1.0
# 4     0  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180            0.0    1955.0
# 1           0     0          3      7        2170          400.0    1951.0
# 2           0     0          3      6         770            0.0    1933.0
# 3           0     0          5      7        1050          910.0    1965.0
# 4           0     0          3      8        1680            0.0    1987.0
#
#    yr_renovated  zipcode  sqft_living15  sqft_lot15
# 0           0.0  98178.0         1340.0      5650.0
# 1        1991.0  98125.0         1690.0      7639.0
# 2           0.0  98028.0         2720.0      8062.0
# 3           0.0  98136.0         1360.0      5000.0
# 4           0.0  98074.0         1800.0      7503.0

# %%
target = df['price'].values
features = df.drop(['price'],axis=1).values

# %%
X_train , X_test , y_train , y_test = train_test_split(features , target , test_size = 0.3,random_state =42)

# %%
model = linear_model.LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-d768f88d541e> in <module>()
# ----> 1 model.fit(X_train, y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# --> 573                     ensure_min_features, warn_on_dtype, estimator)
#     574     if multi_output:
#     575         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     451                              % (array.ndim, estimator_name))
#     452         if force_all_finite:
# --> 453             _assert_all_finite(array)
#     454
#     455     shape_repr = _shape_repr(array.shape)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X)
#      42             and not np.isfinite(X).all()):
#      43         raise ValueError("Input contains NaN, infinity"
# ---> 44                          " or a value too large for %r." % X.dtype)
#      45
#      46
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
predict = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-31-a8e767840cfa> in <module>()
# ----> 1 predict = model.predict(X_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     254             Returns predicted values.
#     255         """
# --> 256         return self._decision_function(X)
#     257
#     258     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in _decision_function(self, X)
#     235
#     236     def _decision_function(self, X):
# --> 237         check_is_fitted(self, "coef_")
#     238
#     239         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     766
#     767     if not all_or_any([hasattr(estimator, attr) for attr in attributes]):
# --> 768         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     769
#     770
#
# NotFittedError: This LinearRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this method.

# %%
accuracy = model.score(X_test, y_test)
mse = mean_squared_error(y_test, predict)
r2 = r2_score(y_test, predict)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-32-23b0bcdce765> in <module>()
# ----> 1 accuracy = model.score(X_test, y_test)
#       2 mse = mean_squared_error(y_test, predict)
#       3 r2 = r2_score(y_test, predict)
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     384
#     385         from .metrics import r2_score
# --> 386         return r2_score(y, self.predict(X), sample_weight=sample_weight,
#     387                         multioutput='variance_weighted')
#     388
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     254             Returns predicted values.
#     255         """
# --> 256         return self._decision_function(X)
#     257
#     258     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in _decision_function(self, X)
#     235
#     236     def _decision_function(self, X):
# --> 237         check_is_fitted(self, "coef_")
#     238
#     239         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     766
#     767     if not all_or_any([hasattr(estimator, attr) for attr in attributes]):
# --> 768         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     769
#     770
#
# NotFittedError: This LinearRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this method.

# %%
print("Accuracy Score: %f\nMean Squared Error: %.02f\nr2 Score: %f"%(accuracy, mse, r2))
